# %% [markdown]
# <a href="https://colab.research.google.com/github/gndede/python/blob/main/Data_Analysis_BeautiflSoup_295.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import I
import pandas as pd
import numpy as np

# %%
#import the following to a df1 file
df1 = pd.read_csv(r'/content/Per_Capita_PPP.csv')

#import the following to a df2 file
df2 = pd.read_csv(r'/content/GCP_per_capita.csv')

#import the following to a df3 file
df3 = pd.read_csv(r'/content/GCP_PPP.csv')

#import the following to a df4 file
df4 = pd.read_csv(r'/content/GDP_Nominal.csv')

# %%
result_dataset = pd.concat([df1, df2, df3, df4], axis=1)
result_dataset.head()

# %%
result_dropped_multiple = result_dataset.drop(['Flag', 'Flag and Name'], axis=1)
result_dropped_multiple.head()

# %%
# Rename multiple columns
df5 = result_dropped_multiple.rename(columns={'No.': 'Number', 'No.': 'Number1'})
df5 = df5.drop(['Number1'], axis=1)
df5.head()

# %%
df5 #.columns)

# %%
#change the order of the columns in order to reorder them.
#df5 = pd.DataFrame(Rank)
#col = df5.pop("Discount")
#df5 = df5.insert(0, col.name, col)
# Move column 'Rank' to the first position
#df5 = df5.reindex(['No.', 'Name', 'Value', 'No.', 'County', 'GCP per Capita (USD)','County', 'GCP (USD) in billions', 'Rank', 'GDP (KES) 000,000','GDP (USD) 000,000'])
#df5 = df5[['Rank', 'Name', 'Value', 'No.', 'County', 'GCP per Capita (USD)','County', 'GCP (USD) in billions', 'GDP (KES) 000,000','GDP (USD) 000,000']]

# %%
#cols = df5.columns.tolist() #['a', 'b', 'c']
#new_cols = [['No.', 'Name', 'Value', 'No.', 'County', 'GCP per Capita (USD)','County', 'GCP (USD) in billions', 'Rank', 'GDP (KES) 000,000','GDP (USD) 000,000']]
#df5 = df5[~df5.index.duplicated(keep='first')] # Keep the first occurrence
#df5 = df5.reindex(['No.', 'Name', 'Value', 'No.', 'County', 'GCP per Capita (USD)','County', 'GCP (USD) in billions', 'Rank', 'GDP (KES) 000,000','GDP (USD) 000,000'])
#df6 = df5.reindex(columns=new_cols)
df5
