# %% [markdown]
# <a href="https://colab.research.google.com/github/gndede/python/blob/main/Python_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#data = pd.read_csv(filename, encoding= 'unicode_escape')
df = pd.read_csv("/content/test _123.csv", encoding= 'unicode_escape')

# %%
df.head()
# Out:
#    coordinatedMailingId  ...                                           planType
# 0              14501776  ...  Medicare Advantage, Medigap, Part D prescripti...
# 1              14645397  ...  Medicare Advantage, Medigap, Part D prescripti...
# 2              14645493  ...  Medicare Advantage, Medigap, Part D prescripti...
# 3              14645843  ...  Medicare Advantage, Medigap, Part D prescripti...
# 4              14645843  ...  Medicare Advantage, Medigap, Part D prescripti...
#
# [5 rows x 18 columns]

# %%
#del df["planType"]

# %%
#del df["customField4"]

# %%
 #del	df["customField5"]

# %%
#del df["pdfName"]
#del df["phoneNumber"]

# %%
#del df["dropDate"]

# %%
#df

# %%
#Group by the coordinatedMailingId
gk = df.groupby(['coordinatedMailingId','asset1','addressLine1','isPrimary'])

# %%
gk.first()
# Out:
#                                                             customerPersonId  ...                                           planType
# coordinatedMailingId asset1         addressLine1 isPrimary                    ...
# 14501776             U1C-EG-DV-2021 268 address  True               14501776  ...  Medicare Advantage, Medigap, Part D prescripti...
# 14645397             U1C-EG-DV-2021 347 address  True               14645397  ...  Medicare Advantage, Medigap, Part D prescripti...
# 14645493             U1C-EG-DV-2021 346 address  True               14645493  ...  Medicare Advantage, Medigap, Part D prescripti...
# 14645843             U1C-EG-DV-2021 348 address  False              14646038  ...  Medicare Advantage, Medigap, Part D prescripti...
#                                                  True               14645843  ...  Medicare Advantage, Medigap, Part D prescripti...
# ...                                                                      ...  ...                                                ...
# 19310556             U1C-EG-DV-2021 21 address   True               19310556  ...  Medicare Advantage, Medigap, Part D prescripti...
# 19310734             U1C-EG-DV-2021 104 address  False              19310734  ...  Medicare Advantage, Medigap, Part D prescripti...
# 19310737             U1C-EG-DV-2021 106 address  False              19310737  ...  Medicare Advantage, Medigap, Part D prescripti...
# 19310738             U1C-EG-DV-2021 105 address  False              19310738  ...  Medicare Advantage, Medigap, Part D prescripti...
# 19310880             U1C-EG-DV-2021 79 address   False              19310880  ...  Medicare Advantage, Medigap, Part D prescripti...
#
# [397 rows x 14 columns]

# %%
#drop ALL duplicate values
#df.drop_duplicates(subset = "customerPersonId", keep = False, inplace = True)

# %%
#drop ALL duplicate values
#df.drop_duplicates(subset = "asset1", keep = False, inplace = True)

# %%
#drop ALL duplicate values
#df.drop_duplicates(subset = "asset2", keep = False, inplace = True)
# Out:
# Empty DataFrame
# Columns: [coordinatedMailingId, customerPersonId, isPrimary, firstName, lastName, fullName, addressLine1, city, state, zip, country, organizationNameForMailing, asset1, asset2, dropDate, pdfName, phoneNumber, planType]
# Index: []

# %%
#df
# Out:
# Empty DataFrame
# Columns: [coordinatedMailingId, customerPersonId, isPrimary, firstName, lastName, fullName, addressLine1, city, state, zip, country, organizationNameForMailing, asset1, asset2, dropDate, pdfName, phoneNumber, planType]
# Index: []

# %%
df['fullName'] = df['firstName'].str.cat(df['lastName'],sep=" ")
#firstName	lastName	fullName

# %%
df
# Out:
#      coordinatedMailingId  ...                                           planType
# 0                14501776  ...  Medicare Advantage, Medigap, Part D prescripti...
# 1                14645397  ...  Medicare Advantage, Medigap, Part D prescripti...
# 2                14645493  ...  Medicare Advantage, Medigap, Part D prescripti...
# 3                14645843  ...  Medicare Advantage, Medigap, Part D prescripti...
# 4                14645843  ...  Medicare Advantage, Medigap, Part D prescripti...
# ..                    ...  ...                                                ...
# 398              19292327  ...  Medicare Advantage, Medigap, Part D prescripti...
# 399              19293226  ...  Medicare Advantage, Medigap, and Part D prescr...
# 400              19293440  ...  Medicare Advantage, Medigap, Part D prescripti...
# 401              19293479  ...  Medicare Advantage, Medigap, Part D prescripti...
# 402              19299993  ...  Medicare Advantage, Medigap, Part D prescripti...
#
# [403 rows x 18 columns]

# %%
# Sorting by column "isPrimary"
df.sort_values(by=['isPrimary'], ascending=False)
# Out:
#      coordinatedMailingId  ...                                           planType
# 0                14501776  ...  Medicare Advantage, Medigap, Part D prescripti...
# 237              19237380  ...  Medicare Advantage, Medigap, Part D prescripti...
# 249              19255254  ...  Medicare Advantage, Medigap, Part D prescripti...
# 248              19247795  ...  Medicare Advantage, Medigap, Part D prescripti...
# 247              19246651  ...  Medicare Advantage, Medigap, Part D prescripti...
# ..                    ...  ...                                                ...
# 108              18452432  ...  Medicare Advantage, Medigap, Part D prescripti...
# 51               17837059  ...  Medicare Advantage, Medigap, Part D prescripti...
# 208              18955730  ...  Medicare Advantage, Medigap, Part D prescripti...
# 324              19308000  ...  Medicare Advantage, Medigap, Part D prescripti...
# 347              19308517  ...  Medicare Advantage, Medigap, Part D prescripti...
#
# [403 rows x 18 columns]

# %%
df['phoneNumber']

for phone_no in df['phoneNumber']: 
  contactphone = "%c-%c%c%c-%c%c%c-%c%c%c%c" % tuple(map(ord,list(str(phone_no)[:11])))

  print(contactphone)
# Out:
# 1-888-598-7545
# 1-855-872-6808
# 1-855-872-6808
# 1-855-872-6808
# 1-855-872-6808
# 1-855-872-6808
# 1-855-238-0490
# 1-855-238-0490
# 1-855-832-0978
# 1-844-448-7300
# 1-844-448-7300
# 1-844-596-0467
# 1-844-809-5244
# 1-844-596-0460
# 1-866-715-4673
# 1-844-620-5728
# 1-866-715-4673
# 1-888-812-2190
# 1-855-832-0971
# 1-855-832-0971
# 1-855-233-5513
# 1-855-233-5513
# 1-855-832-0971
# 1-855-832-0971
# 1-844-353-0772
# 1-844-638-4642
# 1-855-832-0976
# 1-855-832-0976
# 1-855-832-0976
# 1-844-596-0460
# 1-855-832-0976
# 1-855-832-0976
# 1-866-202-9691
# 1-888-812-2190
# 1-844-889-9143
# 1-844-889-9143
# 1-844-889-9143
# 1-844-889-9143
# 1-855-832-0976
# 1-855-832-0976
# 1-855-238-0490
# 1-844-596-0467
# 1-855-671-6086
# 1-844-809-5244
# 1-844-809-5244
# 1-844-809-5244
# 1-844-809-5244
# 1-844-809-5244
# 1-888-812-2190
# 1-888-429-8490
# 1-866-356-0166
# 1-844-596-0460
# 1-844-596-0467
# 1-844-287-9945
# 1-844-287-9945
# 1-844-596-0460
# 1-844-596-0460
# 1-888-429-8490
# 1-888-598-7545
# 1-888-598-7545
# 1-866-451-4616
# 1-866-451-4616
# 1-855-241-5720
# 1-855-832-0976
# 1-844-448-7300
# 1-844-448-7300
# 1-844-596-0460
# 1-877-495-6386
# 1-844-448-7300
# 1-844-448-7300
# 1-855-671-6086
# 1-844-256-0921
# 1-855-651-5058
# 1-855-241-5717
# 1-844-596-0460
# 1-866-202-9574
# 1-866-356-1034
# 1-844-596-0467
# 1-855-832-0971
# 1-844-448-7300
# 1-844-448-7300
# 1-888-794-1519
# 1-844-596-0467
# 1-844-448-7300
# 1-844-686-0485
# 1-888-864-0764
# 1-888-864-0764
# 1-844-596-0460
# 1-844-596-0467
# 1-855-671-6086
# 1-888-264-0638
# 1-844-448-7300
# 1-866-259-2944
# 1-844-596-0460
# 1-866-766-6019
# 1-855-835-3916
# 1-855-241-5720
# 1-844-596-0467
# 1-844-596-0460
# 1-844-596-0460
# 1-844-448-7300
# 1-866-682-4841
# 1-866-682-4841
# 1-855-241-5720
# 1-844-287-9945
# 1-888-812-2190
# 1-844-596-0460
# 1-866-766-6019
# 1-855-881-7868
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0460
# 1-844-596-0467
# 1-844-889-9143
# 1-844-889-9143
# 1-844-889-9143
# 1-866-508-5118
# 1-855-323-8831
# 1-855-323-8831
# 1-855-323-8831
# 1-855-323-8831
# 1-855-323-8831
# 1-855-323-8831
# 1-855-323-8831
# 1-844-809-5243
# 1-844-809-5243
# 1-866-249-7785
# 1-888-429-8490
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-855-835-3811
# 1-855-835-3811
# 1-855-241-5724
# 1-866-844-4340
# 1-866-844-4340
# 1-888-230-0074
# 1-888-230-0074
# 1-888-230-0074
# 1-888-230-0074
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-844-287-9945
# 1-866-682-4841
# 1-855-835-3827
# 1-855-835-3827
# 1-855-835-3827
# 1-855-835-3827
# 1-855-663-4227
# 1-855-238-0489
# 1-866-682-4741
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-844-448-7300
# 1-855-663-4228
# 1-855-663-4228
# 1-855-663-4228
# 1-855-663-4228
# 1-855-238-0485
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-844-686-0483
# 1-866-201-0367
# 1-866-201-0367
# 1-866-201-0367
# 1-888-812-2190
# 1-866-766-6019
# 1-855-835-3916
# 1-855-241-5720
# 1-844-596-0467
# 1-844-596-0460

# %%
df['phoneNumber']


for phone_no in df['phoneNumber']:
    contactphone = "%c-%c%c-%c%c%c-%c%c%c%c" % tuple(map(ord,list(str(phone_no)[:11])))
    print(contactphone)

# %%
df = df.assign(phone=[2, 2, 4, 7, 4, 1],
               Identity=[0, 1, 1, 3, 2, 5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-fb71ab46ecc4> in <module>()
#       1 df = df.assign(phone=[2, 2, 4, 7, 4, 1],
# ----> 2                Identity=[0, 1, 1, 3, 2, 5])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in assign(self, **kwargs)
#    3697
#    3698         for k, v in kwargs.items():
# -> 3699             data[k] = com.apply_if_callable(v, data)
#    3700         return data
#    3701
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (6) does not match length of index (403)
