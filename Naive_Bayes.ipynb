# %% [markdown]
# <a href="https://colab.research.google.com/github/gndede/python/blob/main/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Naive Bayes**
#
# Naive Bayes comes under supervising machine learning which used to make classifications of data sets and predict things based on its prior knowledge and independence assumptions.
#
# ![615isSOjY1L._AC_SL1200_.jpg](data:image/jpeg;base64,...)
#
#
# They call it naive because it’s assumptions (it assumes that all of the features in the data set are equally important and independent) are really optimistic and rarely true in most real-world applications.
#
# **Naive Bayes Algorithm:** It is a classification algorithm that makes the decision for the unknown data set. It is based on Bayes Theorem which describes the probability of an event based on its prior knowledge.
#
# It is widely used for text classification which used in various applications like Google search, email sorting, language detection, etc. The below diagram shows how N.B achieve predictions.
#
# ![1_t4MgLqWdO9DYSLZT4qnQbQ.png](data:image/png;base64,...)
#
# It is used to check prior probabilities of the data set and along with that, it will provide new probabilities.
# Prior probabilities always divided in 50%–50% for all data sets and the job of the algorithm is to decide which class label it belongs, based on currently existing objects.
#
# **For eg: Weight and Height are the parameters which decide whether players are Sumo wrestlers or Basketball players. Initially, it divided into two parts which are equally distributed.**
#
# ![1__a_RvLIGsqrMie68APg73A.png](data:image/png;base64,...)
#
# **The formula to predict NB:**
#
# ![1_NayvGYDQ8MGqHPcx6an1DQ.png](data:image/png;base64,...)
#
# Above,
# a) P(H|E) is the posterior probability of class (H, target) given predictor (E, attributes).
#
# b) P(H) is the prior probability of class.
#
# c) P(E|H) is the likelihood which is the probability of predictor given class.
#
# d) P(E) is the prior probability of predictor.
#
# **How to use the Naive Bayes Algorithm?**
#
# **Use Case:** With below weather conditions and corresponding target variable ‘Play’ (suggesting possibilities of playing). Now, we need to classify whether players will play or not based on weather conditions. Let’s follow the below steps to perform it.
# **Step 1:** First we find out the Likelihood of the table which shows the probability of yes or no in the below diagram.
# **Step 2:** Find the posterior probability of each class.
#
# ![1_xjcvaqvVaTQ2II5k1P9TJg.png](data:image/png;base64,...)
#
# **Problem:** Find out the possibility of whether the player plays in a Rainy condition?
#
# P(Yes|Rainy) = P(Rainy|Yes) * P(Yes) / P(Rainy)
#
# P(Rainy|Yes) = 2/9 = 0.222
# P(Yes) = 9/14 = 0.64
# P(Rainy) = 5/14 = 0.36
#
# Now, P(Yes|Rainy) = 0.222*0.64/0.36 = 0.39 which is a lower probability which means chances of the match played are low.
#
# **Usage naive Bayes algorithm:**
#
# 1. If you have a moderate or large training data set.
# 2. If the instances have several attributes.
# 3. Given the classification parameter, attributes that describe the instances should be conditionally independent.
# 4. When there are limited resources in terms of memory and CPU.
# 5. It is less computationally intensive.
#
# **Pros and cons of Naive Bayes Algorithm?**
# **Pros :**
# 1. Easy to implement
# 2. Less model complexity
# 3. Less CPU computation.
# 4. Performing good when the data set is small.
#
# **Cons :**
#
# 1. Very strong assumption due to these results is bad, it called naively.
# 2. Data scarcity
# 3. Real-life problems such as no variable dependency.
# 4. Not performing well when data is too large and it’s the assumption that all features are independent.
#
# **More reference:** https://stackoverflow.com/questions/10059594/a-simple-explanation-of-naive-bayes-classification
#
#
# **Gaussian Naive Bayes model:**
# It is used in classification and it assumes that features follow a normal distribution.
#
# **Multinomial Naive Bayes model:**
# It is used for discrete counts. For example, let’s say,  we have a text classification problem.
# Here we can consider bernoulli trials which is one step further and instead of “word occurring in the document”,
# we have “count how often word occurs in the document”,
# you can think of it as “number of times outcome number x_i is observed over the n trials”.
#
# **Bernoulli Naive Bayes model:**
# The binomial model is useful
# if your feature vectors are binary (i.e. zeros and ones).
# One application would be text classification with ‘bag of words’ model where the 1s & 0s are
# “word occurs in the document” and “word does not occur in the document” respectively.
#
# The world of probability, use model to take decisions. Depends on observable pattern, Analayzing pattern which only
# has two outcome.It perform well as linear classifiers.
#
# **Used for:**
# 1. Diagnosis analysis.
# 2. Email spam.
# 3. Text classification.
# 4. Sentiment analysis.
#
# **Note:** Bayes therom describe the probability of an event, Based on the prior
# knowledge of conditions that might related to event.
